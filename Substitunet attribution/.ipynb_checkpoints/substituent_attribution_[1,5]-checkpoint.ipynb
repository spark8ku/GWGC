# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from rdkit import Chem

import xgboost as xgboost
import catboost as catboost
from sklearn import ensemble
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from bayes_opt import BayesianOptimization
from rdkit.Chem import AllChem

# %%
cuma_branch_sol_emi = pd.read_csv("../data/cuma_branch in D4C DB/cuma_branch_sol_emi.csv")

# %% [markdown]
# # combination of substituents(position1, position5)

# %%
# connsidering position1 and position5
locom_int_list=[[1,5]]

# 20 common subgstituents smiles
common_20_subgroup_df = pd.read_csv('../data/common_20_subgroups.csv')
common_20_subgroup=np.array(common_20_subgroup_df['sub smiles'])

# Union of all substituents at each position in DB and 20 common substituents"
a=list(cuma_branch_sol_emi['1'].drop_duplicates())
a= list(set(a) | set(common_20_subgroup))

e=list(cuma_branch_sol_emi['5'].drop_duplicates())
e= list(set(e) | set(common_20_subgroup))

subgroup_6_smiles=[]
sub_list=[a, np.array([]), np.array([]),np.array([]),e,np.array([])]

for li in sub_list:
    subgroup_6_smiles.append(li)
subgroup_6_smiles
# Out:
# [['*C=Cc1ccc(C=O)s1',
#   '*c1nccs1',
#   '*C=Cc1ccc(C=C(C#N)C(=O)O)s1',
#   '*C(=O)ON1C(=O)CCC1=O',
#   '*c1nc2cc(C(=O)Nc3ccc(C)cc3[N+](=O)[O-])ccc2o1',
#   '*n1cc(C(=C)C)nn1',
#   '*c1cc(-c2ccc(SC)cc2)c(-c2ccccc2)o1',
#   '*n1cc(-c2cccc(CC(=O)CCCC(=O)O)c2)nn1',
#   '*C=C(C#N)c1nc2ccccc2s1',
#   '*c1nc2c3ccccc3c3ccccc3c2n1-c1ccc(-c2ccc(-c3nc(-c4ccccc4)nc(-c4ccccc4)n3)cc2)cc1',
#   '*c1cc(-c2ccccc2OC)c(-c2ccccc2)o1',
#   '*c1nn(-c2ccccc2)c(C(=O)OCC)c1C(=O)OC',
#   '*C=Cc1sc2ccccc2[n+]1C',
#   '*C=Cc1ccc(-c2ccccc2)cc1',
#   '*c1nc2c3ccccc3c3ccccc3c2n1-c1ccc(C#N)cc1',
#   '*c1nc2cc(Cl)ccc2s1',
#   '*n1cc(-c2cccc(F)c2)nn1',
#   '*c1nc2c3ccccc3c3ccccc3c2n1-c1ccc(-c2ccc(-n3c4ccccc4c4ccccc43)cc2)cc1',
#   '*C=CC(=O)OCC',
#   '*c1cc(-c2ccc(Br)cc2)c(-c2ccccc2)o1',
#   '*CC(=O)ON1C(=O)CCC1=O',
#   '*C(Cl)=CC=CC(=C(C#N)C#N)c1ccc2c(c1)c1ccccc1n2CC',
#   '*C(=O)OC',
#   '*c1nc2cc(C(=O)Nc3ccccc3[N+](=O)[O-])ccc2o1',
#   '*C(C=Cc1c[nH]c2ccccc12)=C(C#N)C#N',
#   '*c1nc2ccc(OC)cc2s1',
#   '*C',
#   '*n1cc(-c2ccccc2N)nn1',
#   '*c1ccc(C=C(C#N)c2ccc([N+](=O)[O-])cc2)s1',
#   '*C1=[O+][B-](F)(F)OC(C=Cc2ccc(N(C)C)cc2)=C1',
#   '*C=Nc1ccc([N+](=O)[O-])cc1',
#   '*c1nc2ccc(Cl)cc2s1',
#   '*n1cc(C(=O)NCC(C(=O)NCC(=O)O)S(=O)(=O)O)nn1',
#   '*n1cc(-c2ccc(CO)cc2)nn1',
#   '*C=Cc1ccc(C(=O)Oc2c(F)c(F)c(S(=O)(=O)[O-])c(F)c2F)s1',
#   '*C#Cc1ccc(N(C)C)cc1',
#   '*c1nc(C)c(C)s1',
#   '*C1CCCCC1',
#   '*c1ccco1',
#   '*n1cc(C(C)(C)O)nn1',
#   '*c1nc2ccccc2n1C',
#   '*C#Cc1ccc(C=C(C#N)C(=O)O)cc1',
#   '*c1cc2ccc(OC)cc2o1',
#   '*C(=O)C=Cc1cn(-c2ccccc2)nc1-c1ccccc1',
#   '*C=C1CCCc2c1[o+]c1cc(N(CC)CC)ccc1c2-c1ccccc1C(=O)O',
#   '*C(NCCCCCCC)C1=C(O)C(=O)c2ccccc2C1=O',
#   '*C=CC(=O)O[Sn](CCCC)(CCCC)CCCC',
#   '*n1cc(-c2ccccc2OC)nn1',
#   '*n1cc(C(C)=CCO)nn1',
#   '*c1ccc(C=C(C#N)C#N)s1',
#   '*c1ccc(C(=O)C=Cc2ccc(C)cc2)cc1',
#   '*C(=O)C=Cc1ccc(N(CC)CC)cc1',
#   '*c1nc(N2CCOCC2)sc1C=CC(=C(C#N)C#N)c1ccccc1',
#   '*C=CC(=C(C#N)C#N)c1ccc(N(C(C)=O)C(C)=O)cc1',
#   '*n1cc(-c2ccccc2F)nn1',
#   '*c1csc(NC(C)=O)c1C#N',
#   '*C(C)=O',
#   '*c1nc2cc(C(=O)Nc3cccc(C)c3)ccc2o1',
#   '*C#N',
#   '*C(=O)Nc1ccc([N+](=O)[O-])cc1',
#   '*C(=O)Nc1ccc(C#N)cc1',
#   '*C=Cc1ccc(C(=O)Oc2c(F)c(F)c(S(=O)(=O)[O-])c(F)c2F)cc1',
#   '*n1cc(-c2ccccc2Cl)nn1',
#   '*c1ccccc1',
#   '*C=Cc1cccc[n+]1C',
#   '*c1nc(-c2ccccc2)c(-c2ccccc2)[nH]1',
#   '*c1cc2c(OC)cccc2o1',
#   '*c1cn2cc3ccccc3cc2n1',
#   '*c1nc(N2CCOCC2)sc1C=C(C#N)C#N',
#   '*c1cn2cc(C)ccc2n1',
#   '*n1cc(-c2cccc(N)c2)nn1',
#   '*C1=CC=CC=C1',
#   '*C(C=Cc1cn(C)c2ccccc12)=C(C#N)C#N',
#   '*C=CC=C(C#N)C#N',
#   '*C=CC(=O)c1ccc(NC(C)=O)cc1',
#   '*c1cc2cccc(OC)c2o1',
#   '*c1nn(-c2ccccc2)c(C(=O)OCC)c1C(=O)OCC',
#   '*C(=O)C=Cc1ccc(C(=C(c2ccc(OC)cc2)c2ccc(OC)cc2)c2ccccc2)cc1',
#   '*c1ccc(F)cc1',
#   '*C(=O)COC(C)=O',
#   '*c1cccc2ccccc12',
#   '*OC',
#   '*c1ccc(C(=O)C=Cc2ccccc2)cc1',
#   '*c1nn(-c2cccc(C)c2)c(C(=O)OCC)c1C(=O)OCC',
#   '*C(=O)COC(=O)CCCCCCCCCCC',
#   '*c1ccc([N+](=O)[O-])cc1',
#   '*c1nn(-c2ccc(OC)cc2)c(C(=O)OCC)c1C(=O)OCC',
#   '*C=CC(=C(C#N)C#N)c1ccc(N(c2ccccc2)c2ccccc2)cc1',
#   '*C=Cc1ccc(S(=O)(=O)[O-])c[n+]1CCCCCC(=O)O',
#   '*c1nnc(-c2ccccc2NC)o1',
#   '*F',
#   '*C(=O)COC(=O)c1ccccc1',
#   '*C(=O)Oc1ccccc1',
#   '*c1ccc(C(=O)C=Cc2ccc(F)cc2)cc1',
#   '*c1cccs1',
#   '*c1nc(C(=O)OCC)cs1',
#   '*N(CC)CC',
#   '*c1ccc(OC)cc1',
#   '*C(=O)OCC',
#   '*C1=[O+][B-](F)(F)OC(C=CC=C2N(C)c3ccccc3C2(C)C)=C1',
#   '*C(=O)C=Cc1cc2ccc3cccc4ccc(c1)c2c34',
#   '*C(=O)N(c1ccccc1)C(C(=O)NCCCC)c1ccccc1',
#   '*CC(=O)[O-]',
#   '*n1cc(-c2ccc(-c3ccccc3)cc2)nn1',
#   '*c1nc2cc(C(F)(F)F)ccc2s1',
#   '*n1cc(-c2ccccc2C(F)(F)F)nn1',
#   '*c1cn2ccccc2n1',
#   '*C=CC=C1CCCc2c1[o+]c1cc(N(CC)CC)ccc1c2-c1ccccc1C(=O)O',
#   '*C#Cc1ccc([N+](=O)[O-])cc1',
#   '*C(=O)Nc1cccc2nsnc12',
#   '*C(=O)C=Cc1ccc(N(C)CCOCCOCCOCCOC)cc1',
#   '*C=CC(=O)O[Sn](c1ccccc1)(c1ccccc1)c1ccccc1',
#   '*C=C',
#   '*c1ccccc1CC#N',
#   '*C=Cc1ccc(C(=O)OC)cc1',
#   '*c1ccc(C2=CC(=C(C#N)C(N)=O)CC(C)(C)C2)s1',
#   '*C=CC=O',
#   '*C1=[O+][B-](F)(F)OC(C=Cc2cc(OC)ccc2OC)=C1',
#   '*O',
#   '*c1nc2ccccc2[nH]1',
#   '*C1=[O+][B-](F)(F)OC(C=Cc2cccs2)=C1',
#   '*c1cn2cc(OC)ccc2n1',
#   '*C=CC(=C(C#N)C#N)c1ccc(NC(C)=O)cc1',
#   '*c1nn(-c2ccc(Br)cc2)c(C(=O)OCC)c1C(=O)OCC',
#   '*C#Cc1ccc(OC(C)C)cc1',
#   '*c1cc(-c2cccnc2)c(-c2ccccc2)o1',
#   '*C#C',
#   '*c1csc(N)c1C#N',
#   '*c1ccc(C#N)cc1',
#   '*c1cc2cc(Br)ccc2o1',
#   '*C=Cc1ccccc1',
#   '*c1nc2cc(-c3ccccc3)ccc2o1',
#   '*C(=O)N(c1ccccc1)C(C(=O)NC(C)(C)C)c1ccccc1',
#   '*n1cc(-c2cccc(C(F)(F)F)c2)nn1',
#   '*C#Cc1ccccc1',
#   '*c1nc2cc(C(=O)Nc3ccccc3)ccc2o1',
#   '*n1cc(-c2ccccn2)nn1',
#   '*C(=O)C=Cc1ccc(N(CC)CC[n+]2ccccc2)cc1',
#   '*c1nc2c3cccc4ccc5cccc(c5c43)c2n1-c1ccc(C(C)(C)C)cc1',
#   '*C=Cc1ccc(OC)cc1',
#   '*c1nn(-c2cccc(F)c2)c(C(=O)OCC)c1C(=O)OCC',
#   '*C#Cc1ccc(OC)cc1',
#   '*n1cc(-c2ccc(F)cc2F)nn1',
#   '*C=Cc1cccc(C)c1',
#   '*c1nc2ccc(-c3ccccc3)cc2s1',
#   '*C(=O)C=Cc1ccc(N(CC)CCC(=O)[O-])cc1',
#   '*n1cc(-c2ccc(N)cc2)nn1',
#   '*c1ccc(-c2nc(-c3ccccc3)c(-c3ccccc3)[nH]2)s1',
#   '*C(CC(O)c1ccc(-c2ccc(Br)cc2)cc1)c1ccccc1',
#   '*c1nc2cc(C(=O)Nc3cccc(OC)c3)ccc2o1',
#   '*n1cc(-c2cccc3ccccc23)nn1',
#   '*C=NNC(=O)Nc1ccccc1',
#   '*C(Cl)=CC=CC(=C(C#N)C#N)c1ccc(N(c2ccccc2)c2ccccc2)cc1',
#   '*C=Cc1ccc([N+](=O)[O-])cc1',
#   '*c1nn(-c2ccc(C)c(C)c2)c(C(=O)OCC)c1C(=O)OCC',
#   '*C=CC(C)(C)C',
#   '*c1cc2cc(OC)ccc2o1',
#   '*c1nc(N2CCOCC2)sc1C=C(C#N)c1nc2ccccc2s1',
#   '*c1ccc(-c2nc3c4ccccc4c4ccccc4c3[nH]2)s1',
#   '*C(=O)O',
#   '*n1cc(-c2ccc(C(F)(F)F)cc2)nn1',
#   '*c1nn(-c2ccc(Cl)cc2)c(C(=O)OCC)c1C(=O)OCC',
#   '*n1cc(-c2cccc(NC(=O)CCCC(=O)O)c2)nn1',
#   '*c1cc(-c2ccc(OC)cc2)c(-c2ccccc2)o1',
#   '*C=Cc1ccc(C(=O)OC)s1',
#   '*C(=O)C=Cc1ccc(N(CCOCCOCCOCCOC)CCOCCOCCOCCOC)cc1',
#   '*n1cc(-c2ccccc2C)nn1',
#   '*C([NH2+]C)C1=C(O)C(=O)c2ccccc2C1=O',
#   '*c1cc2cc(Cl)ccc2o1',
#   '*C(=O)c1cccs1',
#   '*c1cc2cc(Br)cc(OC)c2o1',
#   '*c1nc2c3ccccc3c3ccccc3c2[nH]1',
#   '*n1cc(-c2ccc(C)cc2)nn1',
#   '*C(F)(F)F',
#   '*C=C(C#N)c1nc2ccccc2o1',
#   '*C(=O)C=CC=C1N(C)c2ccccc2C1(C)C',
#   '*c1nc2c3ccccc3c3ccccc3c2n1-c1ccc(C(C)(C)C)cc1',
#   '*c1ccc(C)cc1',
#   '*C=Cc1ccc(C=Cc2ccc(C=C(C#N)C(=O)O)cc2)cc1',
#   '*C=C(C#N)C#N',
#   '*C=CC(=C(C#N)C#N)c1ccc(N)cc1',
#   '*C(=O)C=Cc1ccc(N(C)C)cc1',
#   '*c1cc2ccccc2o1',
#   '*c1ccc(C=C(C#N)C(=O)OCC)s1',
#   '*c1nc2ccccc2o1',
#   '*c1ccc(-c2ccc3c(c2)C2(c4ccccc4Oc4ccccc42)c2ccccc2-3)cc1',
#   '*N',
#   '*C=O',
#   '*c1ccc2ccccc2c1',
#   nan,
#   '*c1nc2cc(C(=O)Nc3ccccc3Cl)ccc2o1',
#   '*C=Cc1ccc(C)cc1',
#   '*[N+](=O)[O-]',
#   '*n1cc(-c2ccc(OC)cc2)nn1',
#   '*C(=O)N(c1ccccc1)C(C(=O)NC(C)(C)C)c1ccc2c(c1)OCO2',
#   '*S(=O)(=O)O',
#   '*C=CC(O)=CC(C)=O',
#   '*c1nc2c(c(=O)n(C)c(=O)n2C)n1C',
#   '*c1ccc(C2=CC(=C(C#N)C#N)CC(C)(C)C2)s1',
#   '*c1ccc(-c2ccccc2)cc1',
#   '*n1cc(-c2cccc(OC)c2)nn1',
#   '*C=Cc1ccc(C=C(C#N)C(=O)O)cc1',
#   '*c1nc2ccccc2n1-c1ccccc1',
#   '*C(=O)C=Cc1ccc([N+](C)(C)C)cc1',
#   '*c1cc(SC)c(C#N)c(=O)o1',
#   '*c1nnc(-c2ccccc2Nc2ccccc2)o1',
#   '*Cl',
#   '*C=Cc1cc[n+](C)cc1',
#   '*n1cc(-c2ccccc2)nn1',
#   '*C(=O)NCCCCC(NC(=O)OCC1c2ccccc2-c2ccccc21)C(=O)O',
#   '*CC(=O)O',
#   '*C(=O)N(C)C',
#   '*c1nc2cc(Cl)ccc2o1',
#   '*c1nc(N2CCOCC2)sc1C=CC1=CC(=C(C#N)C#N)CC(C)(C)C1',
#   '*C(=O)N(c1ccccc1)C(C(=O)NCCCC)c1ccc2c(c1)OCO2',
#   '*C=Cc1ccc(C=O)cc1',
#   '*C(N)=O',
#   '*C#Cc1ccc(C#N)cc1',
#   '*n1cc(-c2ccccc2Br)nn1',
#   '*n1cc(-c2ccc(NC(=O)CCCC(=O)O)cc2)nn1',
#   '*C#CC(=O)NCC(C(=O)NCC(=O)O)S(=O)(=O)O',
#   '*C=CC(=C(C#N)C#N)c1ccc2c(c1)c1ccccc1n2CC',
#   '*C=Cc1ccc(F)cc1',
#   '*C(=O)C=Cc1ccc(N(CCC(=O)[O-])CCC(=O)[O-])cc1',
#   '*C(=O)C=Cc1ccc(N(CC)CCOCCOCCOCCOC)cc1',
#   '*C(C=Cc1ccc(N(C)C)cc1)=C(C#N)C#N',
#   '*n1cc(-c2ccc(CCCCC)cc2)nn1',
#   '*c1cc2cc(OC)c(OC)cc2o1',
#   '*c1nc2ccccc2s1',
#   '*c1ccc(Br)cc1',
#   '*c1nn(-c2cccc(Cl)c2)c(C(=O)OCC)c1C(=O)OCC',
#   '*C=CC(=O)O',
#   '*CC',
#   '*c1ccc(Cl)cc1',
#   '*c1ccc(C(=O)C=Cc2ccc(C(F)(F)F)cc2)cc1',
#   '*C(C=Cc1ccc(N(c2ccccc2)c2ccccc2)cc1)=C(C#N)C#N',
#   '*C(=O)C=Cc1ccc(N(CC[n+]2ccccc2)CC[n+]2ccccc2)cc1',
#   '*c1cc(-c2ccc3ccccc3c2)c(-c2ccccc2)o1',
#   '*C=Cc1ccc(Cl)cc1',
#   '*c1ccc(-n2c3ccccc3c3ccccc32)cc1',
#   '*C=Cc1cccc[n+]1CCCS(=O)(=O)[O-]',
#   '*C(=O)c1ccccc1O'],
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  ['*O',
#   '*OCCC[P+](c1ccccc1)(c1ccccc1)c1ccccc1',
#   '*NN=C1C(=O)NC(c2ccccc2)=C1C(=O)OCC',
#   '*N1CC2(COC2)C1',
#   '*C(C)=O',
#   '*N(C)C',
#   '*n1cc(-c2ccc(N(C)CC#Cc3cn(C4CC(O[Si](C)(C)C(C)(C)C)C(CO[Si](C)(C)C(C)(C)C)O4)c(=O)[nH]c3=O)cc2)nn1',
#   '*OCCOCCOCCOC',
#   '*C=Cc1cc2c(c(OC)c1)OC1(C)CCC(O)C(C)(C)C1C2',
#   '*C#Cc1ccc(OC(C)C)cc1',
#   '*C#N',
#   '*N',
#   '*C#C',
#   '*OCCCCC[Se]C#N',
#   '*[O-]',
#   '*Nc1cccc2nsnc12',
#   '*OCCC[NH3+]',
#   '*c1nc(-c2ccccc2)c(-c2ccccc2)[nH]1',
#   nan,
#   '*[N+](=O)[O-]',
#   '*C#Cc1ccccc1',
#   '*C1=CC=CC=C1',
#   '*S(=O)(=O)O',
#   '*N1CC2(CCNCC2)C1',
#   '*C#Cc1ccc(OC)cc1',
#   '*Cl',
#   '*NC(=O)CCC(N)C(=O)O',
#   '*NC(=O)OCC',
#   '*[NH+]=CC=C1C=C(C(=O)O)NC(C(=O)O)C1',
#   '*OC(=O)C=C',
#   '*OC',
#   '*OCCCC',
#   '*OC(C)=O',
#   '*c1csc2ccccc12',
#   '*C(=O)OC',
#   '*c1ccc(C(F)(F)F)cc1',
#   '*N(c1ccccc1)c1ccccc1',
#   '*C',
#   '*N(c1cccc(O)c1)c1cccc(O)c1',
#   '*c1ccsc1',
#   '*C(N)=O',
#   '*N=P(c1ccc(C(F)(F)F)cc1)(c1ccc(C(F)(F)F)cc1)c1ccc(C(F)(F)F)cc1',
#   '*N=P(c1ccccc1)(c1ccccc1)c1ccccc1',
#   '*F',
#   '*N(CC)CC',
#   '*OCCCCCC',
#   '*c1cccs1',
#   '*N=Cc1ccc2cccc(O)c2n1',
#   '*C(=O)O',
#   '*OC(=O)c1ccccc1',
#   '*OCC=C(C)C',
#   '*OCC',
#   '*N(c1ccccc1)c1cccc(O)c1',
#   '*NCC',
#   '*C#Cc1ccc(N(C)C)cc1',
#   '*N1CCC1',
#   '*CC',
#   '*c1cc2ccccc2s1',
#   '*OCCCCCCCCCC',
#   '*C(F)(F)F',
#   '*C1CCCCC1',
#   '*c1cn(Cc2ccccc2)nn1',
#   '*N1CCS(=O)(=O)CC1',
#   '*N=P(c1ccc(OC)cc1)(c1ccc(OC)cc1)c1ccc(OC)cc1',
#   '*C=C',
#   '*c1ccc(OC)c(OC)c1'],
#  array([], dtype=float64)]

# %%
# all combination of substituent smiles
from tqdm import tqdm
from itertools import product

chunk_size = 10000

input_smiles_final = []
current_batch = []


for locom in locom_int_list:
    subsmiles_in_comb = [subgroup_6_smiles[locations-1] for locations in locom]
    for combo in product(*subsmiles_in_comb):
        branch_stand = ['loc1','loc2','loc3','loc4','loc5','loc6']
        for idx, loc in enumerate(locom):
            branch_stand[loc-1] = combo[idx]
        current_batch.append(branch_stand)     
        if len(current_batch) >= chunk_size:
            input_smiles_final.append(np.vstack(current_batch))
            current_batch =[]


if current_batch:
    input_smiles_final.append(np.vstack(current_batch))
    
input_smiles_final_array = np.vstack(input_smiles_final)

# %% [markdown]
# # Using XGBoost model for emission wavelength

# %%
from functions.conv_input_Gauss_function import one_touch_representation_Gauss

cuma_branch_sol_emi = pd.read_csv("../data/cuma_branch in D4C DB/cuma_branch_sol_emi.csv")
X_emi= one_touch_representation_Gauss(cuma_branch_sol_emi,10,  10*( 0.6645613384222082/10), True)

Y_emi = np.array(cuma_branch_sol_emi['Emi']).flatten()
scaler = StandardScaler()
scaled_Y_emi = scaler.fit_transform(Y_emi.reshape(-1,1)).flatten()


xgb = xgboost.XGBRegressor(n_estimators = 89, learning_rate= 0.12170962342182974, subsample =0.6765177031554993, max_depth = 9, random_state=42)
xgb.fit(X_emi, scaled_Y_emi)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.12170962342182974,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=89, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# # augment & predict (in DMF)

# %%
def augmentes_X_conv_input_in_sol(solvent, sub_smiles_combo, conv_range, sigma_ratio):

    
    chunk_size = 10000
    current_batch = []
    augmented_x_conv=[]
    
    
    #solvent_conv
    sol_feature, sol_adj = _make_matrix([solvent], conv_range, sigma_ratio, True) 
    sol_matirx = np.dot(sol_adj[0], sol_feature[0])
    sol_conv_1D = np.dot(np.ones(sol_adj[0].shape[0]),sol_matirx)
    
    
    cuma_mol = Chem.MolFromSmiles('O=C1C=CC2=CC=CC=C2O1')
    core_sub_site_order = [2,3,5,6,7,8]
    
    #만든 조합 중에 폐기 되는 애들 인덱스 수집
    deleted_combi=[]
    for n in tqdm(range(len(sub_smiles_combo))):
        
        # get_sub_atom_index
        core = [Chem.MolFromSmarts('[#8]=[#6:1]1:[#6:2](-[#101:3]):[#6:4](-[#102:5]):[#6:6]2:[#6:7](-[#103:8]):[#6:9](-[#104:10]):[#6:11](-[#105:12]):[#6:13](-[#106:14]):[#6:15]:2:[#8:16]:1')]
    
        where_sub_is=[]
        what_sub_is=[]
        skip_to_next_n = False 
        
        for sub_loc, sub_smiles in enumerate(sub_smiles_combo[n]):
            if sub_smiles[0]=='*':

                chain = Chem.MolFromSmarts(sub_smiles.replace('*','',1))
                if chain is None:
                    print(f"Skipping invalid SMILES: {sub_smiles}, moving to next n")
                    deleted_combi.append(n)
                    skip_to_next_n = True 
                    break 
                
                core = Chem.ReplaceSubstructs(core[0], Chem.MolFromSmarts(f'[#{sub_loc+101}]'),chain)
                if core is None or not isinstance(core, tuple):
                    print(f"Invalid core after ReplaceSubstructs for sub_loc {sub_loc}, sub_smiles {sub_smiles}")
                    deleted_combi.append(n)
                    skip_to_next_n = True 
                    break 
                where_sub_is.append(sub_loc)
                what_sub_is.append(sub_smiles)
                
            else : 
                core = Chem.ReplaceSubstructs(core[0], Chem.MolFromSmarts(f'[#{sub_loc+101}]'),Chem.MolFromSmarts('[#1]'))
                continue
    
        if skip_to_next_n:
            continue  

        try:
            whole_mol = Chem.MolFromSmiles(Chem.MolToSmiles(core[0]))
        except Exception as e:
            print(f"Error in MolToSmiles : smiles which is augmented: {e}")
            deleted_combi.append(n)
            continue
        
        core_idx = whole_mol.GetSubstructMatches(cuma_mol)[0]
    
        sub_atomidx_list = []
        for m in range(len(where_sub_is)):
            sub_idx_candidates = whole_mol.GetSubstructMatches(Chem.MolFromSmiles(what_sub_is[m].replace('*','C',1)))
            sub_idx_candidates = np.array(sub_idx_candidates)
    
            core_site = np.isin(sub_idx_candidates, core_idx[core_sub_site_order[where_sub_is[m]]])
            scam_check = np.isin(sub_idx_candidates, core_idx)
            pick_correct_one = np.where((core_site.any(axis=1))&(np.sum(scam_check, axis=1)==1))[0][0]
            
            sub_idx = list(sub_idx_candidates[pick_correct_one])
            sub_idx.remove( core_idx[core_sub_site_order[where_sub_is[m]]] )
            sub_atomidx_list.append(sub_idx)
    
        
        # making Gaussian weighted graph convolution matirx
        new_feature, new_adj = _make_matrix([Chem.MolToSmiles(core[0])], conv_range, sigma_ratio, True)
        feature_matirx = np.dot(new_adj[0], new_feature[0])
    
    
        #making subgruop_modular_GGC_input
        all_subs_conv_1D = np.zeros(6*45)
        for x in range(len(sub_atomidx_list)):
            sub_conv = feature_matirx[sub_atomidx_list[x],:]
            sub_conv_1D = np.dot(np.ones(len(sub_atomidx_list[x])), sub_conv)
            all_subs_conv_1D[where_sub_is[x]*45:(where_sub_is[x]+1)*45] = sub_conv_1D
        if sub_atomidx_list:   
            del_sub_atoms = np.hstack(sub_atomidx_list)
        else:
            del_sub_atoms = np.array([])

        if del_sub_atoms.size > 0 :
            core_conv = np.delete(feature_matirx, del_sub_atoms, axis=0)
        else:
            core_conv = feature_matirx.copy()

        core_conv_1D = np.dot(np.ones(feature_matirx.shape[0]-len(del_sub_atoms)), core_conv)
    
        conv_branch = np.hstack((sol_conv_1D, core_conv_1D, all_subs_conv_1D)) 
        
        current_batch.append(conv_branch)
        if len(current_batch) >= chunk_size:
                augmented_x_conv.append(np.vstack(current_batch))
                current_batch =[]
    
    

    if current_batch:
        augmented_x_conv.append(np.vstack(current_batch))
        
    augmented_x_conv_final = np.vstack(augmented_x_conv)
    return augmented_x_conv_final, deleted_combi

# %%
from functions.conv_input_Gauss_function import _make_matrix, predict_chunky
import gc

for sol, solname in zip(['CN(C)C=O'], ['DMF']):
    print(f'solvent : {solname} ({sol})')
    augmented_x_conv_final, deleted_combi = augmentes_X_conv_input_in_sol(sol, input_smiles_final_array, 10, 0.6645613384222082)

    all_predict = predict_chunky(augmented_x_conv_final, 10000, xgb)
    all_predict = scaler.inverse_transform(all_predict.reshape(-1,1)).reshape(all_predict.shape[0],)
    np.save(f'augment_predict_{solname}', all_predict)

    del all_predict  
    gc.collect()
# Out:
# solvent : DMF (CN(C)C=O)
# 100%|██████████| 15972/15972 [00:31<00:00, 513.54it/s]

# %% [markdown]
# # Attribution of 20 substituents to emission wavelength (in DMF)

# %%
solname = 'DMF'
predict_on_sol = np.load(f"augment_predict_{solname}.npy")

# %%
input_smiles_final_array=np.delete(input_smiles_final_array, deleted_combi, axis=0)

location_chunk = 20
delta_basic_20=[]
delta_basic_6loc=[]

for loc in [0,4]:
    for subidx in np.arange(20):
        
        predict_stand = predict_on_sol[input_smiles_final_array[:,loc] == common_20_subgroup[subidx]] # in DMF
        print(f'loc : {loc}, index : {subidx}',len(predict_stand))
    
        sub_combo_observe = input_smiles_final_array[input_smiles_final_array[:,loc] == common_20_subgroup[subidx]].astype(object).copy()
        sub_combo_observe[:,loc] = 'deleted'
        input_compare, deletes_combi2 = augmentes_X_conv_input_in_sol('CN(C)C=O', sub_combo_observe, 10, 0.6645613384222082) 
        
        predict_compare = predict_chunky(input_compare, 10000, xgb)
        predict_compare = scaler.inverse_transform(predict_compare.reshape(-1,1)).reshape(predict_compare.shape[0],)
        delta = predict_stand - predict_compare
        delta_basic_20.append(delta)
    
        if len(delta_basic_20) >= location_chunk:
            delta_basic_6loc.append(delta_basic_20)
            delta_basic_20 = []
# Out:
# loc : 0, index : 0 66
# 100%|██████████| 66/66 [00:00<00:00, 804.09it/s]
# loc : 0, index : 1 66
# 100%|██████████| 66/66 [00:00<00:00, 806.25it/s]
# loc : 0, index : 2 66
# 100%|██████████| 66/66 [00:00<00:00, 812.11it/s]
# loc : 0, index : 3 66
# 100%|██████████| 66/66 [00:00<00:00, 814.53it/s]
# loc : 0, index : 4 66
# 100%|██████████| 66/66 [00:00<00:00, 789.56it/s]
# loc : 0, index : 5 66
# 100%|██████████| 66/66 [00:00<00:00, 813.46it/s]
# loc : 0, index : 6 66
# 100%|██████████| 66/66 [00:00<00:00, 805.76it/s]
# loc : 0, index : 7 66
# 100%|██████████| 66/66 [00:00<00:00, 805.72it/s]
# loc : 0, index : 8 66
# 100%|██████████| 66/66 [00:00<00:00, 811.43it/s]
# loc : 0, index : 9 66
# 100%|██████████| 66/66 [00:00<00:00, 806.62it/s]
# loc : 0, index : 10 66
# 100%|██████████| 66/66 [00:00<00:00, 806.95it/s]
# loc : 0, index : 11 66
# 100%|██████████| 66/66 [00:00<00:00, 812.08it/s]
# loc : 0, index : 12 66
# 100%|██████████| 66/66 [00:00<00:00, 806.59it/s]
# loc : 0, index : 13 66
# 100%|██████████| 66/66 [00:00<00:00, 810.75it/s]
# loc : 0, index : 14 66
# 100%|██████████| 66/66 [00:00<00:00, 806.64it/s]
# loc : 0, index : 15 66
# 100%|██████████| 66/66 [00:00<00:00, 813.46it/s]
# loc : 0, index : 16 66
# 100%|██████████| 66/66 [00:00<00:00, 806.01it/s]
# loc : 0, index : 17 66
# 100%|██████████| 66/66 [00:00<00:00, 812.88it/s]
# loc : 0, index : 18 66
# 100%|██████████| 66/66 [00:00<00:00, 807.42it/s]
# loc : 0, index : 19 66
# 100%|██████████| 66/66 [00:00<00:00, 807.28it/s]
# loc : 4, index : 0 242
# 100%|██████████| 242/242 [00:00<00:00, 688.81it/s]
# loc : 4, index : 1 242
# 100%|██████████| 242/242 [00:00<00:00, 687.55it/s]
# loc : 4, index : 2 242
# 100%|██████████| 242/242 [00:00<00:00, 689.02it/s]
# loc : 4, index : 3 242
# 100%|██████████| 242/242 [00:00<00:00, 692.49it/s]
# loc : 4, index : 4 242
# 100%|██████████| 242/242 [00:00<00:00, 694.64it/s]
# loc : 4, index : 5 242
# 100%|██████████| 242/242 [00:00<00:00, 683.06it/s]
# loc : 4, index : 6 242
# 100%|██████████| 242/242 [00:00<00:00, 676.95it/s]
# loc : 4, index : 7 242
# 100%|██████████| 242/242 [00:00<00:00, 682.60it/s]
# loc : 4, index : 8 242
# 100%|██████████| 242/242 [00:00<00:00, 685.61it/s]
# loc : 4, index : 9 242
# 100%|██████████| 242/242 [00:00<00:00, 685.08it/s]
# loc : 4, index : 10 242
# 100%|██████████| 242/242 [00:00<00:00, 684.89it/s]
# loc : 4, index : 11 242
# 100%|██████████| 242/242 [00:00<00:00, 683.05it/s]
# loc : 4, index : 12 242
# 100%|██████████| 242/242 [00:00<00:00, 682.20it/s]
# loc : 4, index : 13 242
# 100%|██████████| 242/242 [00:00<00:00, 684.54it/s]
# loc : 4, index : 14 242
# 100%|██████████| 242/242 [00:00<00:00, 684.65it/s]
# loc : 4, index : 15 242
# 100%|██████████| 242/242 [00:00<00:00, 684.73it/s]
# loc : 4, index : 16 242
# 100%|██████████| 242/242 [00:00<00:00, 688.18it/s]
# loc : 4, index : 17 242
# 100%|██████████| 242/242 [00:00<00:00, 685.79it/s]
# loc : 4, index : 18 242
# 100%|██████████| 242/242 [00:00<00:00, 686.35it/s]
# loc : 4, index : 19 242
# 100%|██████████| 242/242 [00:00<00:00, 688.46it/s]

# %%
common_subgroup_shift_DMF = pd.DataFrame([])
for idx,loc in enumerate([1,5]):
    common_subgroup_shift_DMF[f'location {loc}'] = [np.mean(delta_basic_6loc[idx][n]) for n in range(20)]
common_subgroup_shift_DMF.index=common_20_subgroup_df['sub name']
common_subgroup_shift_DMF.index.name = 'functional group'
print(common_subgroup_shift_DMF)
# Out:
#                   location 1  location 5
# functional group
# Methyl             10.983792   12.412516
# Ethyl               7.015224   10.874872
# Cyclohexyl         47.025200   31.509027
# Ethene             24.906406   21.038454
# Ethyne             16.882908   15.626418
# Phenyl             34.630173   25.093435
# Hydroxyl           23.657850   25.335402
# Amine              39.328056   34.321701
# diethylamine       40.387280   52.087658
# acetyl             52.471394   44.534466
# Carboxyl           49.423782   47.004784
#  -COOMe            52.374172   48.557415
# Fluorine           16.251076   16.237654
# Chlorine           14.709478   16.434126
# Amide              58.190693   72.131203
# Nitrile            34.661121   35.945934
# Nitro              74.214394   79.310776
# Sulfonyl           35.842663   54.125599
# Methoxy            31.507383   17.187984
# Trifluoromethyl    17.182785   19.611876

# %%
common_subgroup_shift_DMF.to_csv('common_subgroup_shift_DMF_[1,5].csv',index = False)

# %%
import seaborn as sns

for idx, position in enumerate([1,5]) :
    fig = plt.figure(figsize=(10,7))
    violin = sns.violinplot(data=delta_basic_6loc[idx])
    plt.title(f'Attribution of functional groups (position{position})', fontsize =27)
    plt.xlim(-1,19.5)
    violin.set_xticks(range(20))
    violin.set_xticklabels(list(common_20_subgroup_df['sub name']), rotation =90, fontsize =25)
    plt.ylabel('Emission λ shift (nm)', fontsize =25)
    plt.yticks(fontsize =22)
    sns.lineplot(x=np.arange(-1,21), y=0, linestyle='--', color ='gray')
   
    plt.tight_layout() 
    fig = violin.get_figure()
    plt.show()
